# %% [markdown]
# <a href="https://colab.research.google.com/github/jaf1123/it612/blob/main/participation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# function addTax(price,rate){
#     return price+(price/rate)
# }
#
# function createBurner(secret,limit){
#     if (limit==0)
#     {
#         return secret
#     }
#     else
#     {
#         return createBurner(secret,limit-1)
#     }
#
# }
# Out:
# Overwriting code.js

# %%
# !node cosde.js
# Out:
# node:internal/modules/cjs/loader:1215
#   throw err;
#   ^
#
# Error: Cannot find module '/content/cosde.js'
#     at Module._resolveFilename (node:internal/modules/cjs/loader:1212:15)
#     at Module._load (node:internal/modules/cjs/loader:1043:27)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:164:12)
#     at node:internal/main/run_main_module:28:49 {
#   code: 'MODULE_NOT_FOUND',
#   requireStack: []
# }
#
# Node.js v20.19.0
